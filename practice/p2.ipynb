# %% [markdown]
# ### **Q1:**
#
# Given an array A of positive integers length N, find the smallest positive integer such that it cannot be represented as the sum of elements of any subset of the given array set.
# - 0 < N <= 10^5
# - 0 < A[i] <= 10^3
#
# Example 1:
# - Input: A[] = [3, 1, 2]
# - Output: 7
#
# Example 2:
# - Input: A[] = [3, 10, 9, 6, 20, 28]
# - Output: 1

# %%
def findSmallestPosNum(A):

# %%
list1 = [3, 1, 2]
print(findSmallestPosNum(list1))
list2 = [3, 10, 9, 6, 20, 28]
print(findSmallestPosNum(list2))

# %% [markdown]
# ### **Q2:**
#
# Given an array A of non-negative numbers length N. Each number is the maximum number of steps you can jump forward from that position.
# - 1 < N <= 10^5
# - 0 < A[i] <= 10^5
#
# For example:
# - If A[i] = 3, you can jump to index i + 1, i + 2, or i + 3 from position i.
# - If A[i] = 0, you cannot jump forward from that position.
#
# Find the minimum number of jumps needed to move from the first position in the array to the last position.
#
# Note:  Return -1 if you can't reach the end of the array.
#
# Example 1:
# - Input: A[] = [1, 3, 5, 8, 9, 2, 6, 7, 6, 8, 9]
# - Output: 3
#
# Example 2:
# - Input: A[] = [1, 4, 3, 2, 6, 7]
# - Output: 2

# %%
def minJump(A):

# %% [markdown]
# ### **Q3:**
#
# Given an integer array arr[] length N. Find the smallest positive number missing from the array.
# - 0 < N <= 10^5
# - -10^6 <= A[i] <= 10^6
#
# Note: Positive number starts from 1. The array can have negative integers too.
#
# Example 1:
# - Input: arr[] = [2, -3, 4, 1, 1, 7]
# - Output: 3
#
# Example 2:
# - Input: arr[] = [5, 3, 2, 5, 1]
# - Output: 4
#
# Example 3:
# - Input: arr[] = [-8, 0, -1, -4, -3]
# - Output: 1

# %% [markdown]
# ### **Q4:**
#
# Given an array arr[], find the first repeating element index. The element should occur more than once and the index of its first occurrence should be the smallest.
#
# Example 1:
# - Input: arr[] = [1, 5, 3, 4, 3, 5, 6]
# - Output: 2
#
# Example 2:
# - Input: arr[] = [1, 2, 3, 4]
# - Output: -1
#
# 1 ≤ arr.size() ≤ 10^6
#
# 0 ≤ arr[i] ≤ 10^6

# %% [markdown]
# ### **Q5:**
#
# Given an array arr[] of integers. Write a program to check whether an arithmetic progression can be formed using all the given elements.
#
# Example 1:
# - Input: arr[] = [0, 12, 4, 8]
# - Output: true
#
# Example 2:
# - Input: arr[] = [12, 40, 11, 20]
# - Output: false
#
# 1 ≤ arr.size() ≤ 10^6
#
# 0 ≤ arr[i] ≤ 10^6
